# %% [markdown]
# # DMD Distraction 다운로드 - Part 1 (Face Only)
#
# **노트북 2/3** | Distraction RGB-IR (s1~s4) | gA~gC + gE-26 = 16개
#
# ⚠️ 서명된 URL → 48시간 후 만료! | face 카메라 + annotation JSON만 저장

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import tarfile
import shutil
import time

# 로컬 임시 폴더
TEMP_DIR = '/content/temp'
os.makedirs(TEMP_DIR, exist_ok=True)

# %% [markdown]
# ## 다운로드 URL 리스트 (16개)

# %%
URLS = [
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gA-1.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=78bfa9707ed411115d221ded96cb8b9a7701a1914ad0d799840e332cee82f9aa",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gA-2.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6f6e9b4efa51e542f567c28d22b0b42dfa0fd582ce002297e1cbc09277061db2",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gA-3.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=e47a2fbeae373209b00e8535b06d0eb55334750696225e439866d523e5e5513d",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gA-4.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=447ec77d8b9be71b5451180b72681ab58960e0296b5ecdadf05c2ecd5e341521",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gA-5.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=2abe2682741675a31d550ba522ee8cda248fd010d4084778980bcb1d357a4282",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gB-6.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=5ab5dcffbb04f488689d365ff0eac4b8c26052b6cc6bdac637e0d35206c6b670",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gB-7.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=950fadc58c0c391757824551a1fab7b64c9dcfea6add256d4e4b9522484ee0fc",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gB-8.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=2e583355e5c9069d1f59d2719576f2ea74b8ac3d902209b317a38d1f80a21726",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gB-9.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=27a7b8619d28a78327c0f842a89f0e572980af1f6c738cc2cd3bd963fb03378f",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gB-10.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=67022cae799e1babf66f009f7ebef6f441471548e320056e2231887524a5ec8a",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gC-11.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=f5d8bd92e20e96a25710dc5fa95348e83116832b6198ae37d7f4526021f239e4",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gC-12.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=e8dad2bdf17f6901d4a1519825ddceefd5705627ddc0d512b163676f44e35fb3",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gC-13.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=873dfc68109b0dba20f7b762aabc832add436591866d099bdc7d1474d19322a1",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gC-14.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=1d84cf3f721275047c2734c9eb75e512961ded69c306a4e5e990133c5c166e79",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gC-15.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=014062c7f679bf6a6b2a3109a8bb5aeda8b4bcf6cc0bf8039146cc6a17bfa8ca",
    "https://datasets.vicomtech.org/di21-dmd-dataset-distraction-rgb-ir/dmd-dataset-rgb_ir-gE-26.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T114842Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=1a26b002a1e93d032d4dc8339129e624bcd51e1b657d0b9e54e880f59ce3110a",
]

print(f'총 {len(URLS)}개 파일')

# %% [markdown]
# ## 다운로드 + 압축해제 + Drive 복사 함수

# %%
DRIVE_BASE = '/content/drive/MyDrive/capstone/DMD/distraction'
os.makedirs(DRIVE_BASE, exist_ok=True)

def process_one_file(url, idx, total):
    """한 파일을 다운로드 → 압축해제 → face+json만 Drive 복사 → 로컬 삭제"""
    filename = url.split('/')[-1].split('?')[0]
    print(f'\n{"="*60}')
    print(f'[{idx}/{total}] {filename}')
    print(f'{"="*60}')
    
    # 1. 다운로드 (로컬)
    tar_path = os.path.join(TEMP_DIR, filename)
    if os.path.exists(tar_path):
        os.remove(tar_path)
    print(f'  1) 다운로드 중...')
    start = time.time()
    # !wget -q --show-progress -O "{tar_path}" "{url}"
    
    if not os.path.exists(tar_path) or os.path.getsize(tar_path) < 1000:
        print(f'  ❌ 다운로드 실패! URL 만료 가능성')
        if os.path.exists(tar_path):
            os.remove(tar_path)
        return False
    
    size_mb = os.path.getsize(tar_path) / (1024*1024)
    elapsed = time.time() - start
    print(f'  → 완료: {size_mb:.0f} MB ({elapsed:.0f}초)')
    
    # 2. 압축 해제 (로컬)
    extract_dir = os.path.join(TEMP_DIR, 'extracted')
    if os.path.exists(extract_dir):
        shutil.rmtree(extract_dir)
    os.makedirs(extract_dir)
    
    print(f'  2) 압축 해제 중...')
    start = time.time()
    try:
        with tarfile.open(tar_path, 'r:gz') as tar:
            tar.extractall(path=extract_dir)
    except Exception as e:
        print(f'  ❌ 압축 해제 실패: {e}')
        # tar.gz가 아닐 수도 있으니 그냥 tar로도 시도
        try:
            with tarfile.open(tar_path, 'r:') as tar:
                tar.extractall(path=extract_dir)
        except:
            print(f'  ❌ tar 해제도 실패. 건너뜀.')
            os.remove(tar_path)
            shutil.rmtree(extract_dir, ignore_errors=True)
            return False
    elapsed = time.time() - start
    print(f'  → 완료 ({elapsed:.0f}초)')
    
    # 3. tar.gz 삭제 (로컬 공간 확보)
    os.remove(tar_path)
    print(f'  3) tar.gz 삭제 완료')
    
    # 4. face 카메라 파일 + JSON만 Drive로 복사
    copied = 0
    skipped = 0
    print(f'  4) Drive로 복사 중...')
    start = time.time()
    for root, dirs, files in os.walk(extract_dir):
        for f in files:
            # face 카메라 파일 + annotation JSON만 복사
            if 'face' in f.lower() or f.endswith('.json'):
                src = os.path.join(root, f)
                rel_path = os.path.relpath(src, extract_dir)
                dst = os.path.join(DRIVE_BASE, rel_path)
                
                # 이미 존재하면 건너뜀
                if os.path.exists(dst) and os.path.getsize(dst) > 0:
                    skipped += 1
                    continue
                
                os.makedirs(os.path.dirname(dst), exist_ok=True)
                shutil.copy2(src, dst)
                copied += 1
            else:
                skipped += 1
    elapsed = time.time() - start
    print(f'  → 복사: {copied}개, 건너뜀: {skipped}개 ({elapsed:.0f}초)')
    
    # 5. 로컬 정리
    shutil.rmtree(extract_dir)
    print(f'  5) 로컬 정리 완료 ✅')
    return True

print(f'Drive 저장 경로: {DRIVE_BASE}')
print(f'로컬 임시 경로: {TEMP_DIR}')

# %% [markdown]
# ## 실행

# %%
# === 다운로드 실행 ===
success = 0
fail = 0
total = len(URLS)

print(f'총 {total}개 파일 처리 시작!')
print(f'예상 소요 시간: 파일당 5~15분\n')

for i, url in enumerate(URLS, 1):
    ok = process_one_file(url, i, total)
    if ok:
        success += 1
    else:
        fail += 1

print(f'\n{"="*60}')
print(f'  완료! 성공: {success}/{total}, 실패: {fail}/{total}')
print(f'{"="*60}')

# %% [markdown]
# ## 결과 확인

# %%
# === Drive에 저장된 파일 확인 ===
total_files = 0
total_size = 0
for root, dirs, files in os.walk(DRIVE_BASE):
    for f in files:
        fpath = os.path.join(root, f)
        total_files += 1
        total_size += os.path.getsize(fpath)

print(f'Drive 저장 경로: {DRIVE_BASE}')
print(f'총 파일 수: {total_files}')
print(f'총 크기: {total_size/(1024**3):.1f} GB')

# 폴더 구조 미리보기
print(f'\n=== 폴더 구조 (3단계까지) ===')
for root, dirs, files in os.walk(DRIVE_BASE):
    level = root.replace(DRIVE_BASE, '').count(os.sep)
    if level < 3:
        indent = '  ' * level
        print(f'{indent}{os.path.basename(root)}/')
        if level == 2:
            subindent = '  ' * (level + 1)
            face_files = [f for f in files if 'face' in f.lower()]
            json_files = [f for f in files if f.endswith('.json')]
            print(f'{subindent}face 비디오: {len(face_files)}개, annotation: {len(json_files)}개')

# %% [markdown]
# # DMD Gaze 데이터셋 다운로드 (Face Only)
#
# **노트북 1/3** | Gaze & Hands (s6) | 15개 파일
#
# ⚠️ 서명된 URL → 48시간 후 만료! | face 카메라 + annotation JSON만 저장

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import tarfile
import shutil
import time

# 로컬 임시 폴더
TEMP_DIR = '/content/temp'
os.makedirs(TEMP_DIR, exist_ok=True)

# %% [markdown]
# ## 다운로드 URL 리스트 (15개)

# %%
URLS = [
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gA-1.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=0d3701d915e661c0500d391bd6650ade4ce1e041f1fe8256b233f1defe1d47b1",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gA-2.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a5be451077e18049abe32005723a5cd019cb78d87689a213a7255195de21b58e",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gA-3.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=dbb7fe24456fb1e0e77fc0d4326921cefde61d45a08c995053d31d7d6038fca6",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gA-4.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=7287a9ecbd28102032b9c196d99dccf55b4e41117a2e4f524442da32045b5c88",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gA-5.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=b351d73dfc9845aae5b0ff1630922ae8c076c2958e3a507057bc9715d63bd499",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gB-6.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=d2dc839710b31e3bfb632d16e8c5a4b2e825ad2b8c5fc24122a36c171b8f809d",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gB-7.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=02e0d29760a83f59ad64584d3379186c57577322b1b390da27348985d3f6a511",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gB-8.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=ce5c8ac50c72e56382ed5b62130bfa0fff91b944577acc555c6192831d0055d6",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gB-9.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=fef853b49fec206a213c4d3999556ebea00cf603705eaf8c0f95b2aace9ccf55",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gB-10.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=4245c00b58357b1ff45e1994a858c9ece79bcec7ceb63ea7b116031a0f1b70d9",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gC-11.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=d1ac55ceb204aa179bc6e4a47cf1cf178f395f70ec887f783806b56fba2b4638",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gC-12.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=ac775ff306305452b1e82002f0cd20440825bae1db0b92ae816d97f80d576ecd",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gC-13.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=45c2fd7bfaa9fb39289d4398cc6cedce759f5a6929344497130f01ac048e35b6",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gC-14.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6a512b3ec049df56796a357015ed806bd4445ebda83a30cdf9f6525efd459fb9",
    "https://datasets.vicomtech.org/di21-dmd-dataset-gaze/dmd-dataset-gaze-gC-15.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Cvu9WzjJuNCiu0Ve%2F20260403%2Feu-vicom-cluster03-ovh%2Fs3%2Faws4_request&X-Amz-Date=20260403T115310Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=df8e17674cee5f2a1c84a7fb1d8da328f2116307ed4365851c94e291e5d0fbb1",
]

print(f'총 {len(URLS)}개 파일')

# %% [markdown]
# ## 다운로드 + 압축해제 + Drive 복사 함수

# %%
DRIVE_BASE = '/content/drive/MyDrive/capstone/DMD/gaze'
os.makedirs(DRIVE_BASE, exist_ok=True)

def process_one_file(url, idx, total):
    """한 파일을 다운로드 → 압축해제 → face+json만 Drive 복사 → 로컬 삭제"""
    filename = url.split('/')[-1].split('?')[0]
    print(f'\n{"="*60}')
    print(f'[{idx}/{total}] {filename}')
    print(f'{"="*60}')
    
    # 1. 다운로드 (로컬)
    tar_path = os.path.join(TEMP_DIR, filename)
    if os.path.exists(tar_path):
        os.remove(tar_path)
    print(f'  1) 다운로드 중...')
    start = time.time()
    # !wget -q --show-progress -O "{tar_path}" "{url}"
    
    if not os.path.exists(tar_path) or os.path.getsize(tar_path) < 1000:
        print(f'  ❌ 다운로드 실패! URL 만료 가능성')
        if os.path.exists(tar_path):
            os.remove(tar_path)
        return False
    
    size_mb = os.path.getsize(tar_path) / (1024*1024)
    elapsed = time.time() - start
    print(f'  → 완료: {size_mb:.0f} MB ({elapsed:.0f}초)')
    
    # 2. 압축 해제 (로컬)
    extract_dir = os.path.join(TEMP_DIR, 'extracted')
    if os.path.exists(extract_dir):
        shutil.rmtree(extract_dir)
    os.makedirs(extract_dir)
    
    print(f'  2) 압축 해제 중...')
    start = time.time()
    try:
        with tarfile.open(tar_path, 'r:gz') as tar:
            tar.extractall(path=extract_dir)
    except Exception as e:
        print(f'  ❌ 압축 해제 실패: {e}')
        # tar.gz가 아닐 수도 있으니 그냥 tar로도 시도
        try:
            with tarfile.open(tar_path, 'r:') as tar:
                tar.extractall(path=extract_dir)
        except:
            print(f'  ❌ tar 해제도 실패. 건너뜀.')
            os.remove(tar_path)
            shutil.rmtree(extract_dir, ignore_errors=True)
            return False
    elapsed = time.time() - start
    print(f'  → 완료 ({elapsed:.0f}초)')
    
    # 3. tar.gz 삭제 (로컬 공간 확보)
    os.remove(tar_path)
    print(f'  3) tar.gz 삭제 완료')
    
    # 4. face 카메라 파일 + JSON만 Drive로 복사
    copied = 0
    skipped = 0
    print(f'  4) Drive로 복사 중...')
    start = time.time()
    for root, dirs, files in os.walk(extract_dir):
        for f in files:
            # face 카메라 파일 + annotation JSON만 복사
            if 'face' in f.lower() or f.endswith('.json'):
                src = os.path.join(root, f)
                rel_path = os.path.relpath(src, extract_dir)
                dst = os.path.join(DRIVE_BASE, rel_path)
                
                # 이미 존재하면 건너뜀
                if os.path.exists(dst) and os.path.getsize(dst) > 0:
                    skipped += 1
                    continue
                
                os.makedirs(os.path.dirname(dst), exist_ok=True)
                shutil.copy2(src, dst)
                copied += 1
            else:
                skipped += 1
    elapsed = time.time() - start
    print(f'  → 복사: {copied}개, 건너뜀: {skipped}개 ({elapsed:.0f}초)')
    
    # 5. 로컬 정리
    shutil.rmtree(extract_dir)
    print(f'  5) 로컬 정리 완료 ✅')
    return True

print(f'Drive 저장 경로: {DRIVE_BASE}')
print(f'로컬 임시 경로: {TEMP_DIR}')

# %% [markdown]
# ## 실행 (위에서부터 순서대로 실행하세요)

# %%
# === 다운로드 실행 ===
success = 0
fail = 0
total = len(URLS)

print(f'총 {total}개 파일 처리 시작!')
print(f'예상 소요 시간: 파일당 5~15분\n')

for i, url in enumerate(URLS, 1):
    ok = process_one_file(url, i, total)
    if ok:
        success += 1
    else:
        fail += 1

print(f'\n{"="*60}')
print(f'  완료! 성공: {success}/{total}, 실패: {fail}/{total}')
print(f'{"="*60}')

# %% [markdown]
# ## 결과 확인

# %%
# === Drive에 저장된 파일 확인 ===
total_files = 0
total_size = 0
for root, dirs, files in os.walk(DRIVE_BASE):
    for f in files:
        fpath = os.path.join(root, f)
        total_files += 1
        total_size += os.path.getsize(fpath)

print(f'Drive 저장 경로: {DRIVE_BASE}')
print(f'총 파일 수: {total_files}')
print(f'총 크기: {total_size/(1024**3):.1f} GB')

# 폴더 구조 미리보기
print(f'\n=== 폴더 구조 (3단계까지) ===')
for root, dirs, files in os.walk(DRIVE_BASE):
    level = root.replace(DRIVE_BASE, '').count(os.sep)
    if level < 3:
        indent = '  ' * level
        print(f'{indent}{os.path.basename(root)}/')
        if level == 2:
            subindent = '  ' * (level + 1)
            face_files = [f for f in files if 'face' in f.lower()]
            json_files = [f for f in files if f.endswith('.json')]
            print(f'{subindent}face 비디오: {len(face_files)}개, annotation: {len(json_files)}개')
